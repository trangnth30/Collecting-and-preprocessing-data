# %% [markdown]
# BÀI TẬP VỀ NHÀ SỐ 7
#
# Tên: Nguyễn Thị Huyền Trang
#
# MSSV: 21520488

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/DS103/BTVN7/train.csv")
data
# Out:
# <ipython-input-6-fe7a08ac38a4>:1: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/DS103/BTVN7/train.csv")
#           id  label               province               district  \
# 0          0      0                    NaN                    NaN
# 1          1      0          Tỉnh Đồng Nai     Thành phố Biên Hòa
# 2          2      0          Tỉnh Đồng Nai       Huyện Long Thành
# 3          3      0       Tỉnh Tuyên Quang  Thành phố Tuyên Quang
# 4          4      0  Thành phố Hồ Chí Minh                 Quận 1
# ...      ...    ...                    ...                    ...
# 29995  29995      0        Tỉnh Quảng Bình       Huyện Quảng Ninh
# 29996  29996      0          Tỉnh Đồng Nai           Huyện Cẩm Mỹ
# 29997  29997      0           Tỉnh Gia Lai         Huyện Krông Pa
# 29998  29998      0       Thành phố Hà Nội            Huyện Ba Vì
# ...

# %% [markdown]
# Số điểm dữ liệu quan sát (dòng) của bộ dữ liệu:

# %%
len(data)
# Out:
# 30000

# %% [markdown]
# Số thuộc tính (cột) của bộ dữ liệu:

# %%
len(data.columns)
# Out:
# 64

# %% [markdown]
# Số ô có giá trị null trong bộ data

# %%
print("num_of_null: ", data.isnull().sum().sum())
# Out:
# num_of_null:  447755
